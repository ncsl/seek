# %%
import collections
import re
import sys
import warnings
from pathlib import Path
from pprint import pprint
import pandas as pd
import nibabel as nb
import numpy as np
import scipy.io

import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mne_bids.tsv_handler import _from_tsv
sys.path.append("../../")

# %%
def visualize_electrodes(img, clusters, radius, threshold, output_fpath):
    import matplotlib
    import matplotlib.pyplot as plt
    from mpl_toolkits.mplot3d import Axes3D

    # get limits based on the image shape in voxels
    xlim, ylim, zlim = img.shape
    axcodes = nb.aff2axcodes(img.affine)

    # rotate the axes and update
    angles = [0, 45, 90, 180, 270, 360]

    # create figure
    fig, axs = plt.subplots(3, 2, figsize=(8,8))

    # generate a rotated figure for each plot
    for i, angle in enumerate(angles):
        ax = axs.flat[i]
        # ax = Axes3D(fig)
        ax.view_init(azim=angle)
        # label_colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k', '0.5']
        for i, electrode in enumerate(clusters):
            clusters_i = []
            clusters_j = []
            clusters_k = []
            for cluster_id in clusters[electrode]:
                for point in clusters[electrode][cluster_id]:
                    clusters_i.append(point[0])
                    clusters_j.append(point[1])
                    clusters_k.append(point[2])
            ax.scatter3D(clusters_i, clusters_j, clusters_k, label=electrode)
        ax.set_xlim3d(0, xlim+1)
        ax.set_ylim3d(0, ylim+1)
        ax.set_zlim3d(0, zlim+1)
        ax.set_title(f'Azim-Angled {angle} Post-Processing Contacts \n'
                     '(Radius = %d voxels, Threshold = %.3f)' % (radius, threshold))
        ax.set_xlabel(f'(x) {axcodes[0]}')
        ax.set_ylabel(f'(x) {axcodes[1]}')
        ax.set_zlabel(f'(x) {axcodes[2]}')
        ax.legend(loc='upper center', bbox_to_anchor=(0.2, 0.8), shadow=True, ncol=1);

    fig.tight_layout()
    plt.savefig(output_fpath, box_inches="tight")
    plt.close(fig)

# %% [markdown]
# # Load in Clustered Voxels

# %%
data_dict = scipy.io.loadmat('/Users/adam2392/Downloads/neuroimg/derivatives/freesurfer/la03/elecs/la03_clusteredelec_voxels.mat')
ch_names = data_dict['eleclabels']
voxel_coords = data_dict['elecmatrix']

print(data_dict.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'eleclabels', 'elecmatrix'])

# %%
print(ch_names.shape)
print(voxel_coords.shape)
# Out:
# (185, 3)
# (185, 3)

# %% [markdown]
# # Load in Electrodes TSV file

# %%
def find_wmchs_in_electrodestsv(fname, atlas_name=None):
    if atlas_name is None:
        atlas_name = ['desikan-killiany', 'destriuex']
    else:
        atlas_name = [atlas_name]
        
    electrodes_tsv = _from_tsv(fname)
    electrodes_df = pd.DataFrame.from_dict(electrodes_tsv)

    atlas_wm_chs = []
    for atlas in atlas_name:
        # get wm from destrieux/dk atlases
        electrodes_df[atlas] = electrodes_df[atlas].str.lower()
        atlas_wm = electrodes_df[electrodes_df[atlas].str.contains("white-matter")]
        wm_chs = atlas_wm['name'].tolist()
        atlas_wm_chs.append(wm_chs)
        print(len(wm_chs))
    
    all_wm_chs = atlas_wm_chs
    wm_chs = set().union(*all_wm_chs)
    wm_chs = [x for x in wm_chs if not x.upper().startswith("L")]
    return wm_chs

# %%
# get wm from destrieux
electrodes_df['desikan-killiany'] = electrodes_df['desikan-killiany'].str.lower()
electrodes_df['destriuex'] = electrodes_df['destriuex'].str.lower()

destrieux_wm = electrodes_df[electrodes_df['destriuex'].str.contains("white-matter")]
dest_wm_chs = destrieux_wm['name'].tolist()

dk_wm = electrodes_df[electrodes_df['desikan-killiany'].str.contains("white-matter")]
dk_wm_chs = dk_wm['name'].tolist()

np.array_equal(dk_wm_chs, dest_wm_chs)
print(set(dest_wm_chs).difference(set(dk_wm_chs)))
print(len(dk_wm_chs))
# Out:
# set()
# 72

# %%
bidsroot = Path("/Users/adam2392/Dropbox/epilepsy_bids/")
derivdir = Path(bidsroot / 'derivatives' / 'freesurfer')
electrodes_fname = Path(bidsroot / 'sub-la03' / 'ses-veeg' / "sub-la03_ses-veeg_acq-seeg_proc-manual_electrodes.tsv")

# use function to find 
wm_chs = find_wmchs_in_electrodestsv(electrodes_fname, atlas_name=None)

# load tsv and df into RAM
electrodes_tsv = _from_tsv(electrodes_fname)
electrodes_df = pd.DataFrame.from_dict(electrodes_tsv)

print(len(wm_chs))
print(wm_chs)

pd.set_option('display.max_rows', None)
display(electrodes_df)
# Out:
# 72
# 72
# 63
# ['F5', 'X8', 'R4', 'W11', 'X7', 'X9', 'C6', 'R5', 'C15', 'W12', 'X6', 'V13', 'Z12', 'Z2', 'C14', 'Z4', 'Z7', 'U1', 'Y11', 'S7', 'S8', 'P9', 'R6', 'Z11', 'W10', 'V14', 'X5', 'C13', 'V12', 'F10', 'S9', 'Z6', 'R8', 'S1', 'W14', 'C9', 'U2', 'F7', 'P14', 'C7', 'F4', 'W5', 'O2', 'F8', 'V7', 'Z13', 'Z3', 'P8', 'V8', 'V2', 'Z10', 'W4', 'R1', 'X10', 'Y3', 'R2', 'C8', 'F9', 'W9', 'W3', 'V11', 'Z5', 'W6']
#     name           x         y        z size  \
# 0     P1    -1.87339  -22.0596  78.9137  n/a
# 1     P2     2.14987  -21.6754  78.3847  n/a
# 2     P3     6.06139  -21.5402  78.5495  n/a
# 3     P8     26.3207  -21.0628  78.8775  n/a
# 4    P11     38.3988  -21.0688  79.5156  n/a
# 5    P12     42.6454  -21.3457  79.6808  n/a
# 6    P13      46.574  -21.2114    79.91  n/a
# 7    P14     50.8417  -20.8784  79.3559  n/a
# 8    P15     55.1192  -20.4045  79.7939  n/a
# 9     W1     -3.1894  -47.3354  73.9111  n/a
# 10    W2  -0.0341944  -47.2043   74.133  n/a
# 11    W3     3.41953  -47.0751  74.3452  n/a
# 12    W4     7.24951  -46.9427  74.5884  n/a
# 13    W5     10.6813  -46.8095  74.7935  n/a
# 14    P9      30.544  -20.9103  79.1513  n/a
# 15   P10     34.5128  -21.2102  79.3113  n/a
# 16    W6     14.4418  -46.5023  74.2297  n/a
# 17    W7     17.9329  -46.3713  74.4264  n/a
# 18    W8     21.6743  -46.6891  74.5818  n/a
# 19    W9     25.0375  -46.5706  74.8322  n/a
# 20   W10     28.5097   -46.905  75.0071  n/a
# 21   W11     32.3066  -46.7855  75.2828  n/a
# 22   W12     35.6176  -46.6566  75.5167  n/a
# 23   W13     39.0123  -46.9943   75.674  n/a
# 24   W14     42.8659  -46.8675  75.9429  n/a
# 25   W15     47.1551  -46.7889    76.34  n/a
# 26   W16     50.9623   -47.124  76.7086  n/a
# 27    V1      -2.185  -53.6634  57.4292  n/a
right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 4                ctx_rh_S_postcentral           ctx-rh-postcentral
# 5                ctx_rh_G_postcentral           ctx-rh-postcentral
# 6                ctx_rh_G_postcentral           ctx-rh-postcentral
# 7         Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 8                             Unknown                      Unknown
# 9                             Unknown                      Unknown
# 10                 ctx_rh_G_precuneus             ctx-rh-precuneus
# 11        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 12        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 13        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 14        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 15               ctx_rh_S_postcentral           ctx-rh-postcentral
# 16        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 17   ctx_rh_S_intrapariet_and_P_trans      ctx-rh-superiorparietal
# 18   ctx_rh_S_intrapariet_and_P_trans      ctx-rh-superiorparietal
# 19        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 20        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 21        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 22        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 23        ctx_rh_G_pariet_inf-Angular      ctx-rh-inferiorparietal
# 24        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 25        ctx_rh_G_pariet_inf-Angular      ctx-rh-inferiorparietal
# 26                            Unknown                      Unknown
# 27                            Unknown                      Unknown
# 28        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 29         ctx_rh_S_parieto_occipital             ctx-rh-precuneus
# 30                    ctx_rh_G_cuneus                ctx-rh-cuneus
# 31                            Unknown                      Unknown
# 32         ctx_rh_S_parieto_occipital             ctx-rh-precuneus
# 33        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 34        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 35    ctx_rh_S_oc_sup_and_transversal      ctx-rh-superiorparietal
# 36    ctx_rh_S_oc_sup_and_transversal      ctx-rh-inferiorparietal
# 37        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 38        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 39        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 40        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 41          ctx_rh_G_occipital_middle      ctx-rh-inferiorparietal
# 42                            Unknown                      Unknown
# 43       ctx_rh_G_cingul-Post-ventral      ctx-rh-isthmuscingulate
# 44        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 45        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 46        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 47        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 48        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 49        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 50        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 51        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 52        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 53        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 54           ctx_rh_G_temporal_middle      ctx-rh-inferiorparietal
# 55                            Unknown                      Unknown
# 56                  Right-Hippocampus            Right-Hippocampus
# 57                  Right-Hippocampus            Right-Hippocampus
# 58                  Right-Hippocampus            Right-Hippocampus
# 59                  Right-Hippocampus            Right-Hippocampus
# 60                  Right-Hippocampus            Right-Hippocampus
# 61        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 62        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 63        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 64        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 65              ctx_rh_S_temporal_sup              ctx-rh-bankssts
# 66              ctx_rh_S_temporal_sup              ctx-rh-bankssts
# 67              ctx_rh_S_temporal_sup              ctx-rh-bankssts
# 68        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 69        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 70        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 71                            Unknown                      Unknown
# 72       ctx_rh_G_oc-temp_med-Lingual               ctx-rh-lingual
# 73       ctx_rh_G_oc-temp_med-Lingual               ctx-rh-lingual
# 74   ctx_rh_S_oc-temp_med_and_Lingual              ctx-rh-fusiform
# 75        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 76        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 77               ctx_rh_S_oc-temp_lat              ctx-rh-fusiform
# 78        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 79        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 80        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 81        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 82              ctx_rh_G_temporal_inf      ctx-rh-inferiortemporal
# 83           ctx_rh_G_temporal_middle        ctx-rh-middletemporal
# 84        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 85        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 86       ctx_rh_G_temp_sup-G_T_transv    ctx-rh-transversetemporal
# 87       ctx_rh_G_temp_sup-G_T_transv      ctx-rh-superiortemporal
# 88       ctx_rh_S_temporal_transverse      ctx-rh-superiortemporal
# 89       ctx_rh_G_temp_sup-Plan_tempo      ctx-rh-superiortemporal
# 90       ctx_rh_G_temp_sup-Plan_tempo      ctx-rh-superiortemporal
# 91                            Unknown                      Unknown
# 92       ctx_rh_G_temp_sup-Plan_tempo      ctx-rh-superiortemporal
# 93                            Unknown                      Unknown
# 94        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 95       ctx_rh_S_circular_insula_sup                ctx-rh-insula
# 96                            Unknown                      Unknown
# 97          ctx_rh_G_and_S_subcentral           ctx-rh-postcentral
# 98          ctx_rh_G_and_S_subcentral           ctx-rh-postcentral
# 99          ctx_rh_G_and_S_subcentral           ctx-rh-postcentral
# 100       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 101       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 102       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 103         ctx_rh_G_and_S_subcentral           ctx-rh-postcentral
# 104       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 105       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 106      ctx_rh_S_circular_insula_sup            ctx-rh-precentral
# 107       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 108       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 109       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 110               ctx_rh_G_precentral            ctx-rh-precentral
# 111       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 112                ctx_rh_G_precuneus             ctx-rh-precuneus
# 113              ctx_rh_S_subparietal             ctx-rh-precuneus
# 114       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 115       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 116             ctx_rh_S_temporal_sup      ctx-rh-inferiorparietal
# 117                           Unknown                      Unknown
# 118       ctx_rh_G_pariet_inf-Angular         ctx-rh-supramarginal
# 119                           Unknown                      Unknown
# 120                           Unknown                      Unknown
# 121       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 122       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 123       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 124       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 125       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 126       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 127                    Right-Amygdala               Right-Amygdala
# 128                    Right-Amygdala               Right-Amygdala
# 129                    Right-Amygdala               Right-Amygdala
# 130                    Right-Amygdala               Right-Amygdala
# 131      ctx_rh_G_oc-temp_med-Lingual               ctx-rh-lingual
# 132       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 133          ctx_rh_G_temporal_middle        ctx-rh-middletemporal
# 134          ctx_rh_G_temporal_middle        ctx-rh-middletemporal
# 135                           Unknown                      Unknown
# 136       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 137       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 138       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 139       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 140       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 141       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 142       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 143                WM-hypointensities           WM-hypointensities
# 144       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 145       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter

# %%
electrodes_fname = Path(bidsroot / 'sub-la05' / 'ses-veeg' / "sub-la05_ses-veeg_acq-seeg_proc-manual_electrodes.tsv")

# use function to find 
wm_chs = find_wmchs_in_electrodestsv(electrodes_fname, atlas_name=None)

# load tsv and df into RAM
electrodes_tsv = _from_tsv(electrodes_fname)
electrodes_df = pd.DataFrame.from_dict(electrodes_tsv)

print(len(wm_chs))
display(electrodes_df)
# Out:
# 72
# 72
# 72
#      name          x         y        z size  \
# 0     X'1    29.9262  -22.1254  41.2848  n/a
# 1     X'2    33.0394  -22.4952  41.1243  n/a
# 2    X'10    61.4804  -22.3307  39.0162  n/a
# 3    X'11    66.2279  -21.8092  38.9681  n/a
# 4     S'1   0.367546  -16.1985  54.8767  n/a
# 5     S'2     4.5369  -15.7588  55.6999  n/a
# 6     S'3    8.85795  -16.1215  55.6933  n/a
# 7     S'4    13.4938  -16.0582  55.5746  n/a
# 8    S'12    49.0232  -16.3063  54.2704  n/a
# 9    S'13    53.2923  -16.2198  54.1065  n/a
# 10   S'14    57.9634  -16.1344  53.9293  n/a
# 11   S'15    62.2669  -16.0424  53.7363  n/a
# 12    X'3    36.8972  -22.4296  40.9468  n/a
# 13    U'1    18.3841  -8.27733  43.8943  n/a
# 14    U'2    21.4519  -8.15193  43.0468  n/a
# 15    U'3    25.3141  -8.07491  42.8614  n/a
# 16    U'4    28.6515  -8.01693  42.7011  n/a
# 17    U'5    32.0307  -7.94755  42.5291  n/a
# 18    U'6    35.7672  -8.32702  42.3155  n/a
right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 9           ctx_rh_G_temp_sup-Lateral      ctx-rh-superiortemporal
# 10          ctx_rh_G_temp_sup-Lateral      ctx-rh-superiortemporal
# 11                            Unknown                      Unknown
# 12        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 13              Right-Thalamus-Proper        Right-Thalamus-Proper
# 14              Right-Thalamus-Proper        Right-Thalamus-Proper
# 15        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 16        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 17        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 18        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 19        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 20        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 21        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 22        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 23        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 24        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 25        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 26           ctx_rh_G_temporal_middle        ctx-rh-middletemporal
# 27           ctx_rh_G_temporal_middle        ctx-rh-middletemporal
# 28                            Unknown                      Unknown
# 29        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 30        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 31        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 32        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 33        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 34        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 35              ctx_rh_S_temporal_inf      ctx-rh-inferiortemporal
# 36              ctx_rh_S_temporal_inf      ctx-rh-inferiortemporal
# 37              ctx_rh_G_temporal_inf      ctx-rh-inferiortemporal
# 38                            Unknown                      Unknown
# 39        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 40        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 41        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 42        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 43        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 44        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 45              ctx_rh_G_temporal_inf      ctx-rh-inferiortemporal
# 46              ctx_rh_G_temporal_inf      ctx-rh-inferiortemporal
# 47              ctx_rh_G_temporal_inf      ctx-rh-inferiortemporal
# 48                            Unknown                      Unknown
# 49            Right-Cerebellum-Cortex      Right-Cerebellum-Cortex
# 50            Right-Cerebellum-Cortex      Right-Cerebellum-Cortex
# 51                            Unknown                      Unknown
# 52       ctx_rh_G_oc-temp_med-Lingual               ctx-rh-lingual
# 53       ctx_rh_G_oc-temp_med-Lingual               ctx-rh-lingual
# 54   ctx_rh_S_oc-temp_med_and_Lingual              ctx-rh-fusiform
# 55       ctx_rh_G_oc-temp_lat-fusifor              ctx-rh-fusiform
# 56        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 57       ctx_rh_G_oc-temp_lat-fusifor              ctx-rh-fusiform
# 58       ctx_rh_G_oc-temp_lat-fusifor              ctx-rh-fusiform
# 59        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 60        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 61        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 62        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 63                            Unknown                      Unknown
# 64                            Unknown                      Unknown
# 65            Right-Cerebellum-Cortex      Right-Cerebellum-Cortex
# 66            Right-Cerebellum-Cortex      Right-Cerebellum-Cortex
# 67            Right-Cerebellum-Cortex      Right-Cerebellum-Cortex
# 68            Right-Cerebellum-Cortex      Right-Cerebellum-Cortex
# 69            Right-Cerebellum-Cortex      Right-Cerebellum-Cortex
# 70            Right-Cerebellum-Cortex      Right-Cerebellum-Cortex
# 71                            Unknown                      Unknown
# 72       ctx_rh_G_oc-temp_lat-fusifor              ctx-rh-fusiform
# 73       ctx_rh_G_oc-temp_lat-fusifor              ctx-rh-fusiform
# 74       ctx_rh_G_and_S_occipital_inf      ctx-rh-lateraloccipital
# 75                            Unknown                      Unknown
# 76                            Unknown                      Unknown
# 77         Left-Cerebral-White-Matter   Left-Cerebral-White-Matter
# 78         ctx_lh_S_cingul-Marginalis    ctx-lh-posteriorcingulate
# 79         Left-Cerebral-White-Matter   Left-Cerebral-White-Matter
# 80        ctx_lh_G_cingul-Post-dorsal    ctx-lh-posteriorcingulate
# 81                            Unknown                      Unknown
# 82                            Unknown                      Unknown
# 83               ctx_rh_S_subparietal      ctx-rh-isthmuscingulate
# 84        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 85        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 86        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 87        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 88        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 89        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 90        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 91        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 92        ctx_rh_S_interm_prim-Jensen         ctx-rh-supramarginal
# 93        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 94        Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 95                ctx_rh_G_precentral            ctx-rh-precentral
# 96                            Unknown                      Unknown
# 97                            Unknown                      Unknown
# 98                            Unknown                      Unknown
# 99                            Unknown                      Unknown
# 100                           Unknown                      Unknown
# 101       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 102          ctx_rh_G_temporal_middle        ctx-rh-middletemporal
# 103                           Unknown                      Unknown
# 104       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 105               ctx_rh_Lat_Fis-post                ctx-rh-insula
# 106      ctx_rh_G_temp_sup-G_T_transv    ctx-rh-transversetemporal
# 107       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 108      ctx_rh_S_temporal_transverse      ctx-rh-superiortemporal
# 109        Left-Cerebral-White-Matter   Left-Cerebral-White-Matter
# 110        Left-Cerebral-White-Matter   Left-Cerebral-White-Matter
# 111        Left-Cerebral-White-Matter   Left-Cerebral-White-Matter
# 112                ctx_lh_G_precuneus             ctx-lh-precuneus
# 113                           Unknown                      Unknown
# 114       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 115                ctx_rh_G_precuneus             ctx-rh-precuneus
# 116             ctx_rh_G_parietal_sup      ctx-rh-superiorparietal
# 117       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 118                           Unknown                      Unknown
# 119             ctx_rh_G_parietal_sup      ctx-rh-superiorparietal
# 120       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 121         ctx_rh_G_occipital_middle      ctx-rh-inferiorparietal
# 122         ctx_rh_G_occipital_middle      ctx-rh-inferiorparietal
# 123                           Unknown                      Unknown
# 124                           Unknown                      Unknown
# 125                ctx_lh_S_calcarine         ctx-lh-pericalcarine
# 126                ctx_lh_S_calcarine         ctx-lh-pericalcarine
# 127                ctx_lh_S_calcarine         ctx-lh-pericalcarine
# 128      ctx_lh_G_oc-temp_med-Lingual               ctx-lh-lingual
# 129                           Unknown                      Unknown
# 130       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 131                ctx_rh_S_calcarine         ctx-rh-pericalcarine
# 132                ctx_rh_S_calcarine         ctx-rh-pericalcarine
# 133       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 134       Right-Cerebral-White-Matter  Right-Cerebral-White-Matter
# 135    ctx_rh_S_oc_middle_and_Lunatus      ctx-rh-lateraloccipital
# 136    ctx_rh_S_oc_middle_and_Lunatus      ctx-rh-lateraloccipital
# 137         ctx_rh_G_occipital_middle      ctx-rh-lateraloccipital
# 138                           Unknown                      Unknown
# 139                           Unknown                      Unknown
# 140      ctx_lh_S_circular_insula_sup                ctx-lh-insula
# 141              Left-Thalamus-Proper         Left-Thalamus-Proper
# 142              Left-Thalamus-Proper         Left-Thalamus-Proper
# 143      ctx_lh_S_circular_insula_sup           ctx-lh-postcentral
# 144        Left-Cerebral-White-Matter   Left-Cerebral-White-Matter
# 145        Left-Cerebral-White-Matter   Left-Cerebral-White-Matter
# 146        Left-Cerebral-White-Matter   Left-Cerebral-White-Matter
# 147        Left-Cerebral-White-Matter   Left-Cerebral-White-Matter
# 148        Left-Cerebral-White-Matter   Left-Cerebral-White-Matter
# 149                           Unknown                      Unknown
# 150                           Unknown                      Unknown
# 151                           Unknown                      Unknown
# 152      ctx_lh_S_circular_insula_inf    ctx-lh-transversetemporal
# 153        Left-Cerebral-White-Matter   Left-Cerebral-White-Matter
# 154        Left-Cerebral-White-Matter   Left-Cerebral-White-Matter
# 155        Left-Cerebral-White-Matter   Left-Cerebral-White-Matter
# 156        Left-Cerebral-White-Matter   Left-Cerebral-White-Matter
# 157      ctx_lh_G_temp_sup-G_T_transv    ctx-lh-transversetemporal
# 158      ctx_lh_G_temp_sup-Plan_tempo      ctx-lh-superiortemporal
# 159         ctx_lh_G_temp_sup-Lateral      ctx-lh-superiortemporal
# 160         ctx_lh_G_temp_sup-Lateral      ctx-lh-superiortemporal
# 161                           Unknown                      Unknown
# 162                           Unknown                      Unknown
# 163                           Unknown                      Unknown
# 164               ctx_lh_Lat_Fis-post      ctx-lh-superiortemporal
# 165               ctx_lh_Lat_Fis-post      ctx-lh-superiortemporal
# 166                           Unknown                      Unknown
# 167      ctx_lh_G_pariet_inf-Supramar         ctx-lh-supramarginal
# 168      ctx_lh_G_pariet_inf-Supramar         ctx-lh-supramarginal
# 169      ctx_lh_G_pariet_inf-Supramar         ctx-lh-supramarginal
# 170                           Unknown                      Unknown
# 171      ctx_lh_G_temp_sup-Plan_tempo      ctx-lh-superiortemporal
# 172                           Unknown                      Unknown
# 173                           Unknown                      Unknown
# 174        Left-Cerebral-White-Matter   Left-Cerebral-White-Matter
# 175         ctx_lh_G_and_S_subcentral           ctx-lh-postcentral
# 176        Left-Cerebral-White-Matter   Left-Cerebral-White-Matter
# 177        Left-Cerebral-White-Matter   Left-Cerebral-White-Matter
# 178        Left-Cerebral-White-Matter   Left-Cerebral-White-Matter
# 179        Left-Cerebral-White-Matter   Left-Cerebral-White-Matter
# 180        Left-Cerebral-White-Matter   Left-Cerebral-White-Matter
# 181        Left-Cerebral-White-Matter   Left-Cerebral-White-Matter
# 182         ctx_lh_G_temp_sup-Lateral              ctx-lh-bankssts
# 183         ctx_lh_G_temp_sup-Lateral              ctx-lh-bankssts
# 184                           Unknown                      Unknown
# 185                           Unknown                      Unknown
